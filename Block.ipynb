# %% [markdown]
# <a href="https://colab.research.google.com/github/ghluque/Analisis_BTC/blob/master/Block.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests

url= 'https://blockchain.info/blocks/1582736905613?format=json&fbclid=IwAR3eEoKFsWtb1E508EqO7qiJtefyd_ZUdJ9PTcaB2VWYDFVMKJl0c5b2LsQ'
r= requests.get(url)

print(r.content)


pd.to_datetime('now')
print(pd.to_datetime('now'))
# Out:
# b'\n\n\n{ \n    "blocks" : [\n    {\n        "height" : 619002,\n        "hash" : "0000000000000000000cfe48631b9dc8083201f7bda4deb5bc081e344d1a5913",\n        "time" : 1582675806,\n        "main_chain" : true\n    },\n    \n    {\n        "height" : 619003,\n        "hash" : "000000000000000000014919fdd4053b744d0374ea06040b5b47c8fce0701a3c",\n        "time" : 1582677403,\n        "main_chain" : true\n    },\n    \n    {\n        "height" : 619004,\n        "hash" : "000000000000000000089a89aa8368dfd6249d1bbcdbe7bdc62a3e962d58cd29",\n        "time" : 1582677495,\n        "main_chain" : true\n    },\n    \n    {\n        "height" : 619005,\n        "hash" : "0000000000000000000336bf59c5c398ee61e0a0f83b21349adfe011319f4d50",\n        "time" : 1582681436,\n        "main_chain" : true\n    },\n    \n    {\n        "height" : 619006,\n        "hash" : "000000000000000000083d2064f9efea06166cd4a2494d34166f0490fa0306ad",\n        "time" : 1582682255,\n        "main_chain" : true\n    },\n    
# ...
